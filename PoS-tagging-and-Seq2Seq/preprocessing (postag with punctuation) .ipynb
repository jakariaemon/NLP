# %%
import stanza

nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos')
text_raw = open('data1.txt', encoding="utf8").read()
doc = nlp(text_raw)
print(*[f'{word.xpos}\t {word.text}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# ...
# 2022-06-30 23:55:05 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2022-06-30 23:55:05 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# ...
#
# 2022-06-30 23:55:05 INFO: Use device: cpu
# 2022-06-30 23:55:05 INFO: Loading: tokenize
# 2022-06-30 23:55:05 INFO: Loading: pos
# 2022-06-30 23:55:05 INFO: Done loading processors!
# RB	 Finally
# NN	 tonight
# ,	 ,
# PRP	 it
# VBZ	 's
# NN	 prom
# NN	 season
# ,	 /
# CC	 and
# NNP	 Steve
# NNP	 Hartman
# VBD	 met
# DT	 the
# NN	 queen
# CC	 and
# PRP$	 her
# NN	 king
# ,	 ,
# ,	 /
# IN	 On
# DT	 the
# NNP	 Road
# .	 .
# IN	 At
# NNP	 Mountain
# NNP	 Heritage
# NNP	 High
# NNP	 School
# IN	 in
# NNP	 Burnsville
# ,	 ,
# NNP	 North
# NNP	 Carolina
# ,	 ,
# ,	 /
# NNP	 Rachel
# NNP	 Newberry
# VBD	 caught
# NNP	 Ben
# NNP	 Robinson
# ,	 /
# RB	 completely
# RP	 off
# NN	 guard
# .	 .
# PRP	 You
# VBD	 did
# ...
